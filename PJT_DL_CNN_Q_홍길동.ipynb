# %% [markdown]
# <a href="https://colab.research.google.com/github/Juikson/master/blob/main/PJT_DL_CNN_Q_%ED%99%8D%EA%B8%B8%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mySUNI_DL_PJT_CNN_Q

# %% [markdown]
# ### 가위 바위 보 이미지 분류

# %% [markdown]
# # STEP 0. Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# # STEP 1. 데이터 다운로드 및 로딩

# %%
pip install wget
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wget
import os
import zipfile

url = 'http://data.jaen.kr/download?download_path=/data/files/mySUNI/05.%20%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%8C%8C%EC%9D%BC/rps.zip'
path = './data/'
filename = 'rps.zip'

if not os.path.exists(path):
    os.makedirs(path)
wget.download(url, out=os.path.join(path, filename))

with zipfile.ZipFile(os.path.join(path, filename), 'r') as zf:
    zf.extractall('data/')
# Out:
#   4% [...                                                                   ]   7307264 / 168166965
#  11% [........                                                              ]  20111360 / 168166965
#  19% [.............                                                         ]  32481280 / 168166965
#  26% [..................                                                    ]  44949504 / 168166965
#  33% [.......................                                               ]  57073664 / 168166965
#  41% [............................                                          ]  69566464 / 168166965
#  48% [..................................                                    ]  81788928 / 168166965
#  55% [.......................................                               ]  93782016 / 168166965
#  63% [............................................                          ] 106995712 / 168166965
# ...

# %%
import glob

# 데이터 확인
glob.glob('./data/rps/*')
# Out:
# ['./data/rps\\train', './data/rps\\validation']

# %% [markdown]
# # STEP 2. 전처리
# `ImageDataGenerator`를 정의합니다.
#
# 다음의 옵션 값들로 Image Aumentation(이미지 변형) 옵션을 적절히 조절해 주세요
#
# * `rescale`: 이미지의 픽셀 값을 조정
# * `rotation_range`: 이미지 회전
# * `width_shift_range`: 가로 방향으로 이동
# * `height_shift_range`: 세로 방향으로 이동
# * `shear_range`: 이미지 굴절
# * `zoom_range`: 이미지 확대
# * `horizontal_flip`: 횡 방향으로 이미지 반전
# * `fill_mode`: 이미지를 이동이나 굴절시켰을 때 빈 픽셀 값에 대하여 값을 채우는 방식

# %% [markdown]
# - 모든 옵션은 자유롭게 설정하세요.

# %%
# Code here

# %% [markdown]
# ImageDataGenerator를 잘 만들어 주었다면, `flow_from_directory`로 이미지를 어떻게 공급해 줄 것인가를 지정해 주어야합니다.
#
# * train / validation의 dataset을 설정합니다.
# * `batch_size`를 정의합니다 (128)
# * `target_size`를 정의합니다. (150 x 150). 이미지를 알아서 타겟 사이즈 만큼 잘라내어 공급합니다.
# * `class_mode`는 3개 이상의 클래스인 경우 'categorical' 이진 분류의 경우 `binary`를 지정합니다.

# %%
# ./data/rps/train/
# Code here
# Out:
# Found 1680 images belonging to 3 classes.

# %%
# ./data/rps/validation/
# Code here
# Out:
# Found 420 images belonging to 3 classes.

# %% [markdown]
# # STEP 3. 모델 구성
#  - Conv2D, MaxPooling2D 조합으로 Sequential 모델을 구성합니다.
#  - 첫 번째 계층의 input_shape은 (150, 150, 3)으로 지정합니다.

# %%
# Code here

# %% [markdown]
# # STEP 4. 컴파일

# %% [markdown]
#  - metrics는 accuracy

# %%
# Code here

# %% [markdown]
# # STEP 5. ModelCheckpoint 생성 (선택)

# %%
# Code here

# %% [markdown]
# # STEP 6. 학습

# %%
# Code here

# %% [markdown]
# # STEP 7. 평가

# %%
# 학습 데이터와 검증 데이터 평가 (loss, accuracy)
